# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(10,70,(50))
print(x)
# Out:
# [55 23 33 30 53 32 29 68 67 55 31 65 22 52 39 25 31 26 53 58 45 22 68 21
#  29 52 15 33 37 66 33 42 25 38 54 36 47 69 69 21 35 58 24 23 67 52 54 15
#  45 69]

# %%
no=[55,23,33,30,53,32,29,68,67,55,31,65,22,52,39,25,31,26,53,58,45,22,68,21,
    29,52,15,33,37,66,33,42,25,38,54,36,47,69,69,21,35,58,24,23,67,52,54,15,45,69]
l=[10,20,30,40,50,60,70]
plt.hist(no,color="b",edgecolor="r",label="python") #range=(0,200), bins=l,cumulative=-1,l #bottom=10, align="mid",rihgt,left, 
                                                    # histtype=step,stepfilled,barstacked,bar  orientation="horizontal"  rwidth=0.8
                                                    # log=True, 
plt.title("HISTOGRAM",fontsize=15)
plt.xlabel("PYTHON",fontsize=15)
plt.ylabel("NO.",fontsize=15)
plt.legend()
plt.show()

# %%
no=[55,23,33,30,53,32,29,68,67,55,31,65,22,52,39,25,31,26,53,58,45,22,68,21,
    29,52,15,33,37,66,33,42,25,38,54,36,47,69,69,21,35,58,24,23,67,52,54,15,45,69]
l=[10,20,30,40,50,60,70]
plt.hist(no,color="b",edgecolor="r",label="python") 

plt.title("HISTOGRAM",fontsize=15)
plt.xlabel("PYTHON",fontsize=15)
plt.ylabel("NO.",fontsize=15)

plt.axvline(40,color="black",label="line")
# plt.grid()
plt.legend()
plt.show()
